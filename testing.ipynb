# %%
import os
os.getcwd()
# Out:
# '/Users/sam/Documents/School/Spring 2024/Neural Networks/final proj/graffiti'

# %%
import rbsHelpers

# %%
rbsHelpers.process("valid")
# Out:
#      index                                           filename  \
# 0       98  52D00735-253B-4A7B-AF52-CE6CF3494806_jpg.rf.b0...
# 1       81  8797A7E6-021B-4F99-98D8-1D1346A5EA7F_jpg.rf.92...
# 2       59  Er-Sub-Erni-NEWAVE1986_jpg.rf.66db95e3790b8782...
# 3       26  IMG_0517_JPG.rf.22edad669f173ac32237d57b1ee45e...
# 4        4  IMG_0788_JPG.rf.00c44989c22cc628b12a79705b4b21...
# ..     ...                                                ...
# 167    155  photojpg_4190490811_o_jpg.rf.efd108a04b84c2e8d...
# 168    143  stak_1591211946_o_jpg.rf.d7df951206f72b61f80db...
# 169    134  swet_2696510297_o_jpg.rf.d0b43515c6c1aec1e7412...
# 170    106  two-truck-dr-sex-tag_122679472_o_jpg.rf.a3c8de...
# 171    135  vfr_1591211004_o_jpg.rf.d3336258b7d61f01a9548e...
#
#                                                pixvals   masterpiece  \
# 0    [[[[-3.939003 30.221    91.32    ], [  8.06099...             0
# 1    [[[[135.061  38.221 -44.68 ], [135.061  38.221...             0
# ...

# %%
st = rbsHelpers.pd.read_csv(os.path.join("graffiti_data","valid_data_full.csv")).iloc[0]["pixvals"]

# %%
def drop_null(lizt):
    cleaned = [item for item in lizt if item != ""]
    return cleaned

# %%
drop_null(str.split("\n"))
# Out:
# ['[[[[  -3.939003    30.221       91.32     ]',
#  '   [   8.060997    40.221      101.32     ]',
#  '   [  11.060997    41.221      107.32     ]',
#  '   ...',
#  '   [-103.939     -116.779     -119.68     ]',
#  '   [-103.939     -116.779     -115.68     ]',
#  '   [-102.939     -113.779     -112.68     ]]',
#  '  [[   8.060997    37.221      105.32     ]',
#  '   [  18.060997    44.221      115.32     ]',
#  '   [  18.060997    44.221      116.32     ]',
#  '   ...',
#  '   [-103.939     -116.779     -119.68     ]',
#  '   [-103.939     -116.779     -115.68     ]',
#  '   [-103.939     -114.779     -113.68     ]]',
#  '  [[   6.060997    28.221      107.32     ]',
#  '   [  13.060997    33.221      112.32     ]',
#  '   [  12.060997    31.221      113.32     ]',
#  '   ...',
#  '   [-103.939     -116.779     -118.68     ]',
#  '   [-103.939     -115.779     -114.68     ]',
#  '   [-103.939     -113.779     -112.68     ]]',
#  '  ...',
# ...
